# %%
DATA UPLOADING

# %%
import pandas as pd

df=pd.read_csv('Sales.csv')

# %%
df.shape
# Out:
# (500000, 14)

# %%
df
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
df.isnull()
# Out:
#         Region  Country  Item Type  Sales Channel  Order Priority  Order Date  \
# 0        False    False      False          False           False       False
# 1        False    False      False          False           False       False
# 2        False    False      False          False           False       False
# 3        False    False      False          False           False       False
# 4        False    False      False          False           False       False
# ...        ...      ...        ...            ...             ...         ...
# 499995   False    False      False          False           False       False
# 499996   False    False      False          False           False       False
# 499997   False    False      False          False           False       False
# 499998   False    False      False          False           False       False
# 499999   False    False      False          False           False       False
#
# ...

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#                          Region           Country  Item Type Sales Channel  \
# 0            Sub-Saharan Africa      South Africa     Fruits       Offline
# 1  Middle East and North Africa           Morocco    Clothes        Online
# 2         Australia and Oceania  Papua New Guinea       Meat       Offline
# 3            Sub-Saharan Africa          Djibouti    Clothes       Offline
# 4                        Europe          Slovakia  Beverages       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M   7/27/2012  443368995   7/28/2012        1593        9.33
# 1              M   9/14/2013  667593514  10/19/2013        4611      109.28
# 2              M   5/15/2015  940995585    6/4/2015         360      421.89
# 3              H   5/17/2017  880811536    7/2/2017         562      109.28
# 4              L  10/26/2016  174590194   12/4/2016        3973       47.45
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt

new_df = pd.read_csv('Sales Records.csv')

plt.figure(figsize=(12, 8))

grouped_data = new_df.groupby('Region').agg({
    'Total Revenue': 'sum',
    'Total Cost': 'sum',
    'Total Profit': 'sum'
})

grouped_data.plot(kind='bar', width=0.8, colormap='viridis')
plt.title('Total Revenue, Total Cost, and Total Profit by Region')
plt.xlabel('Region')
plt.ylabel('Amount')
plt.xticks(rotation=45, ha='right')
plt.legend(["Total Revenue", "Total Cost", "Total Profit"])
plt.show()

# %%
print(new_df.columns)
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Sales Records.csv')  # Replace 'your_file.csv' with your actual file path

df['Order Date'] = pd.to_datetime(df['Order Date'])

df['Profit Margin'] = df['Total Profit'] / df['Total Revenue']

df.sort_values(by='Order Date', inplace=True)


top_items = df.groupby('Item Type')['Total Revenue'].sum().head(10)
plt.figure(figsize=(10, 6))
top_items.plot(kind='bar', color='skyblue')
plt.title('Top Selling Items by Total Revenue')
plt.xlabel('Item Type')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45, ha='right')
plt.show()

sns.set(style='whitegrid', palette='pastel')

plt.figure(figsize=(10, 6))
top_items_units_sold =  df.groupby('Item Type')['Units Sold'].sum().head(10)
plt.figure(figsize=(10, 6))
top_items.plot(kind='bar', color='skyblue')
plt.title('Top Selling Items by Total Revenue')
plt.xlabel('Item Type')
plt.ylabel('Unit Sold')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Sales Records.csv')

df['Order Date'] = pd.to_datetime(df['Order Date'])

df['Profit Margin'] = df['Total Profit'] / df['Total Revenue']

df.sort_values(by='Order Date', inplace=True)

top_items_revenue = df.groupby('Item Type')['Total Revenue'].sum().head(10)
plt.figure(figsize=(10, 6))
top_items_revenue.plot(kind='bar', color='skyblue')
plt.title('Top Selling Items by Total Revenue')
plt.xlabel('Item Type')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45, ha='right')
plt.show()

sns.set(style='whitegrid', palette='pastel')

plt.figure(figsize=(10, 6))
top_items_units_sold = df.groupby('Item Type')['Units Sold'].sum().head(10)
plt.bar(top_items_units_sold.index, top_items_units_sold, color='Green')
plt.title('Top Selling Items by Total Units Sold')
plt.xlabel('Item Type')
plt.ylabel('Units Sold')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Sales Records.csv')

df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

df = df.dropna(subset=['Order Date'])


df_aggregated = df.groupby('Order Date')['Total Profit'].mean().reset_index()

df_aggregated.sort_values(by='Order Date', inplace=True)

plt.figure(figsize=(12, 6))
plt.plot(df_aggregated['Order Date'], df_aggregated['Total Profit'], linestyle='-', color='green', label='Mean Profit Margin')
plt.title('Trend of Mean Profit Over Time')
plt.xlabel('Order Date')
plt.ylabel('Profit')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('Sales Records.csv')

plt.pie(df['Sales Channel'].value_counts(), autopct='%1.1f%%', 
        startangle=90, labels=df['Sales Channel'].value_counts().index)
plt.title('Sale Distribution across diffrent channel')
plt.legend()
plt.show()

# %%
import pandas as pd
import sweetviz

data=pd.read_csv('Sales Records.csv')

# %%
Sales_report=sweetviz.analyze([data,'Total Profit'],target_feat='Total Profit')

# %%
Sales_report.show_html('Sales_Record_Report.html')

# %%
print(df.columns)
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
correlation_matrix = df[numeric_columns].corr()

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
sns.heatmap(df[['Total Profit', 'Units Sold', 'Unit Price', 'Unit Cost']].corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
sns.pairplot(df[['Total Profit', 'Units Sold', 'Unit Price', 'Unit Cost']])
plt.show()
# Out:
# C:\Users\HINAL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.iloc[:, :-1]
y = df.iloc[:, -1]

x_train,x_test,y_test,y_train= train_test_split(x, y, test_size=0.3, random_state=0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.preprocessing import LabelEncoder
import pandas as pd

data = pd.read_csv('Sales Records.csv')

target_columns = ['Units Sold', 'Unit Price','Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit']  # Replace with your actual target column names

for target in target_columns:
    X = data[['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
              'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
              'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit']]
    
    y = data[target]

    label_encoder = LabelEncoder()
    
    for column in X.select_dtypes(include=['object']).columns:
        X[column] = label_encoder.fit_transform(X[column])

    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error  
from sklearn.metrics import r2_score

linreg = LinearRegression()
linreg.fit(x_train, y_train)

    # Make predictions
y_pred = linreg.predict(x_test)

    # Evaluate the model using R-squared
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test,y_pred)

print(f"R-squared for {target}: {r2}")
print(f"Mean Squared Error: {mse}")
# Out:
# R-squared for Total Profit: 1.0
# Mean Squared Error: 2.815485928948741e-15

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(x_train, y_train)

    # Make predictions
y_pred = logreg.predict(x_test)

    # Evaluate the model using R-squared 
r2 = r2_score(y_test, y_pred)

print(f"R-squared for {target}: {r2}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 4
#       1 from sklearn.linear_model import LogisticRegression
#       3 logreg = LogisticRegression()
# ----> 4 logreg.fit(x_train, y_train)
#       6     # Make predictions
#       7 y_pred = logreg.predict(x_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1215, in LogisticRegression.fit(self, X, y, sample_weight)
#    1205     _dtype = [np.float64, np.float32]
# ...

# %%
pip install --upgrade scikit-learn

# %%
from sklearn.ensemble import RandomForestRegressor 
from sklearn.metrics import mean_squared_error  
from sklearn.metrics import r2_score

rf_regressor = RandomForestRegressor(random_state=20, n_estimators=100, max_depth=10)

rf_regressor.fit(x_train, y_train)

y_pred = rf_regressor.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test , y_pred)

print(f"Mean Squared Error: {mse}")
print(f'R-squared : {r2}')

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

knn_regressor = KNeighborsRegressor(n_neighbors = 5)  
knn_regressor.fit(x_train, y_train)

y_pred = knn_regressor.predict(x_test)
r2 = r2_score(y_test,knn_pred)

mse = mean_squared_error(y_test, knn_pred)
print(f"Mean Squared Error: {mse}") 
print(f'R-squared : {r2}')
# Out:
# Mean Squared Error: 3269672354.0067625
# R-squared : 0.9771289260308788

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

tree_regressor = DecisionTreeRegressor(max_depth=10)  
tree_regressor.fit(x_train, y_train)

y_pred = tree_regressor.predict(x_test)
r2=r2_score(y_test,dt_pred)

mse = mean_squared_error(y_test, dt_pred)
print(f"Mean Squared Error: {mse}")
print(f'R-squared : {r2}')
# Out:
# Mean Squared Error: 165501.8770061147
# R-squared : 0.9999988423287531

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

svm_model = SVR(kernel ='linear')
svm_model.fit(x_train, y_train) 

y_pred = svm_model.predict(x_test)  
r2 = r2_score(y_test, y_pred) 

mse = mean_squared_error(y_test, y_pred) 
print(f"Mean Squared Error: {mse}")
print(f'R-squared: {r2}')

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import r2_score

gb_model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
gb_model.fit(x_train, y_train)

y_pred=gb_model.predict(x_test)
r2 = r2_score(y_test,gb_pred)

mse = mean_squared_error(y_test,gb_pred)
print(f"Mean Squared Error : {mse}")
print(f'R-Squared : {r2}')
# Out:
# Mean Squared Error : 7930237.110545603
# R-Squared : 0.9999445286805799

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

np.random.seed(42)
x_train, x_test, y_train, y_test = np.random.rand(50, 5), np.random.rand(10, 5), np.random.rand(50), np.random.rand(10)


models = [
    ("Linear Regression", LinearRegression()),
    ("Random Forest Regression", RandomForestClassifier()),
    ("KNN Regression", KNeighborsRegressor()),
    ("Decision Tree Regression", DecisionTreeRegressor()),
    ("Gradient Boosting Regression", GradientBoostingRegressor())
]

# Loop through models
for model_name, model in models:
    # Train the model
    model.fit(x_train, y_train)
    
    # Make predictions
    y_pred = model.predict(x_test)
    
    # Display regression metrics
    print(f"\nMetrics for {model_name}:")
    print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
    print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
    print("R-squared:", r2_score(y_test, y_pred))
# Out:
# Metrics for Linear Regression:
# Mean Absolute Error: 0.27469285694041085
# Mean Squared Error: 0.09585933900129764
# R-squared: -0.06323160812962647
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 27
#      24 # Loop through models
#      25 for model_name, model in models:
#      26     # Train the model
# ---> 27     model.fit(x_train, y_train)
#      29     # Make predictions
#      30     y_pred = model.predict(x_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming x_train, y_train, x_test, y_test are already defined

# Initialize regression models
models = [
    ('Random Forest Regressor', RandomForestRegressor()),
    ('Decision Tree Regressor', DecisionTreeRegressor()),
    ('Linear Regression', LinearRegression()),
    ('KNN Regressor', KNeighborsRegressor()),
    ('Gradient Boosting Regressor', GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42))
]

mse_scores = []
r2_scores = []

# Train and evaluate each model
for model_name, model in models:
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    mse_scores.append(mse)
    r2_scores.append(r2)
    
    print(f"{model_name} - Mean Squared Error: {mse}, R-squared: {r2}")

# Plotting Mean Squared Error
plt.figure(figsize=(10, 6))
sns.barplot(x=[model[0] for model in models], y=mse_scores, palette='magma').set_title('Model Comparison (Mean Squared Error)')
plt.xticks(rotation=45)
plt.ylabel('Mean Squared Error')
plt.show()

# Plotting R-squared;l-;,m        
plt.figure(figsize=(10, 6))
sns.barplot(x=[model[0] for model in models], y=r2_scores, palette='magma').set_title('Model Comparison (R-squared)')
plt.xticks(rotation=45)
plt.ylabel('R-squared')
plt.show()
# Out:
# Random Forest Regressor - Mean Squared Error: 56.68036427890188, R-squared: 0.9999999996038769
# Decision Tree Regressor - Mean Squared Error: 158.20386579614308, R-squared: 0.9999999988943576
# Linear Regression - Mean Squared Error: 2.815485928948741e-15, R-squared: 1.0
# KNN Regressor - Mean Squared Error: 3249282952.0673423, R-squared: 0.9772916754929603
# Gradient Boosting Regressor - Mean Squared Error: 8030599.955452587, R-squared: 0.9999438763959727
